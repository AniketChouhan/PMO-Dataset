# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Roads = pd.read_excel("C:/Users/HP/Downloads/Roads_excel.xlsx")

# %%
Roads.head()
# Out:
#                 State    2008  2009  2010  2011  2012  2013   2008.1 2009.1  \
# 0      Andhra Pradesh  4472.0  4537  4537  4537  4537  5022  10518.0  10470
# 1   Arunachal Pradesh   392.0  1992  1992  1992  2027  2027      0.0     ..
# 2               Assam  2836.0  2836  2836  2836  2940  2940   3134.0   3134
# 3               Bihar  3642.0  3642  3642  3642  4105  4168   3767.0   3989
# 4        Chhattisgarh  2184.0  2184  2184  2184  2289  2289   3419.0   3213
#
#   2010.1  ... 2012.3 2013.3 2008.4 2009.4  2010.4  2011.4  2012.4  2013.4  \
# 0  10481  ...  13759  13628   8657   7463    7476    7453    7507    7620
# 1     ..  ...     53     18   1118   1088    1088    1088    5699    5699
# 2   3134  ...   6710   4518   8061   8087    8298    8493   11348   13090
# 3   3989  ...   8918   8760   2328   2850    2850    2850    2848    2848
# 4   5240  ...   8116   8109  15054  15204   15345   15557   15575   18241
#
#    2012.5  2013.5
# 0  164026  168516
# 1    3345    5262
# ...

# %%
Roads['Total_KM'] = Roads.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\1642748258.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Roads['Total_KM'] = Roads.sum(axis=1)

# %%
Total_KM = Roads[['State','Total_KM']].sort_values(by = 'Total_KM', ascending = False).head(3)
Total_KM
# Out:
#              State   Total_KM
# 14     Maharashtra  1077849.0
# 25   Uttar Pradesh   857927.0
# 21       Rajasthan   523078.0

# %% [markdown]
# # National Highway

# %%
NH = pd.read_excel("C:/Users/HP/Downloads/National_Highway.xlsx")

# %%
NH
# Out:
#                  State  2008  2009  2010  2011  2012  2013
# 0       Andhra Pradesh  4472  4537  4537  4537  4537  5022
# 1    Arunachal Pradesh   392  1992  1992  1992  2027  2027
# 2                Assam  2836  2836  2836  2836  2940  2940
# 3                Bihar  3642  3642  3642  3642  4105  4168
# 4         Chhattisgarh  2184  2184  2184  2184  2289  2289
# 5                  Goa   269   269   269   269   269   269
# 6              Gujarat  3245  3245  3245  3245  4032  3828
# 7              Haryana  1512  1512  1518  1518  1633  1633
# 8     Himachal Pradesh  1208  1409  1409  1409  1506  1506
# 9     Jammu & Kashmir   1245  1245  1245  1245  1245  1695
# 10           Jharkhand  1805  1805  1805  1805  2170  2374
# 11           Karnataka  3843  4396  4396  4396  4396  4642
# 12              Kerala  1457  1457  1457  1457  1457  1457
# 13      Madhya Pradesh  4670  4670  5027  5027  5064  5116
# 14         Maharashtra  4176  4176  4191  4191  4257  4498
# ...

# %%
 NH.replace({2009:{'..':0}},inplace=True)
 NH.replace({2010:{'..':0}},inplace=True)
 NH.replace({2011:{'..':0}},inplace=True)
 NH.replace({2012:{'..':0}},inplace=True)
 NH.replace({2013:{'..':0}},inplace=True)

# %%
NH.dtypes
# Out:
# State    object
# 2008      int64
# 2009      int64
# 2010      int64
# 2011      int64
# 2012      int64
# 2013      int64
# dtype: object

# %%
NH['Total_KM_National_Highway'] = NH.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\1298292936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   NH['Total_KM_National_Highway'] = NH.sum(axis=1)

# %%
National_Highway = NH[['State','Total_KM_National_Highway']].sort_values(by = 'Total_KM_National_Highway', ascending = False).head(3)
National_Highway
# Out:
#               State  Total_KM_National_Highway
# 25    Uttar Pradesh                      41832
# 21        Rajasthan                      36650
# 13   Madhya Pradesh                      29574

# %% [markdown]
# # StateHighway

# %%
SH = pd.read_excel("C:/Users/HP/Downloads/State Highway.xlsx")

# %%
SH
# Out:
#                  State   2008   2009   2010   2011   2012   2013
# 0       Andhra Pradesh  10518  10470  10481  10491  10650  10700
# 1    Arunachal Pradesh      0     ..     ..     ..     ..     ..
# 2                Assam   3134   3134   3134   3134   3134   3134
# 3                Bihar   3767   3989   3989   3989   4857   4483
# 4         Chhattisgarh   3419   3213   5240   5240   5240   5240
# 5                  Goa    279    279    279    279    279    279
# 6              Gujarat  18447  18460  18421  18421  18480  18506
# 7              Haryana   2523   2523   2521   2521   2521   2416
# 8     Himachal Pradesh   1824   1626   1626   1626   1626   1504
# 9     Jammu & Kashmir      67     67     67     67     67      …
# 10           Jharkhand   1886   1886   1886   1886   1886   1960
# 11           Karnataka  20738  20905  20528  20770  20774  20749
# 12              Kerala   4137   4341   4341   4341   4341   4341
# ...

# %%
SH.replace({2009:{'..':0}},inplace=True)
SH.replace({2010:{'..':0}},inplace=True)
SH.replace({2011:{'..':0}},inplace=True)
SH.replace({2012:{'..':0}},inplace=True)
SH.replace({2013:{'..':0}},inplace=True)
SH.replace({2013:{'…':0}},inplace=True)

# %%
SH
# Out:
#                  State   2008   2009   2010   2011   2012   2013
# 0       Andhra Pradesh  10518  10470  10481  10491  10650  10700
# 1    Arunachal Pradesh      0      0      0      0      0      0
# 2                Assam   3134   3134   3134   3134   3134   3134
# 3                Bihar   3767   3989   3989   3989   4857   4483
# 4         Chhattisgarh   3419   3213   5240   5240   5240   5240
# 5                  Goa    279    279    279    279    279    279
# 6              Gujarat  18447  18460  18421  18421  18480  18506
# 7              Haryana   2523   2523   2521   2521   2521   2416
# 8     Himachal Pradesh   1824   1626   1626   1626   1626   1504
# 9     Jammu & Kashmir      67     67     67     67     67      0
# 10           Jharkhand   1886   1886   1886   1886   1886   1960
# 11           Karnataka  20738  20905  20528  20770  20774  20749
# 12              Kerala   4137   4341   4341   4341   4341   4341
# ...

# %%
SH.dtypes
# Out:
# State    object
# 2008      int64
# 2009      int64
# 2010      int64
# 2011      int64
# 2012      int64
# 2013      int64
# dtype: object

# %%
SH['Total_KM_State_Highway'] = SH.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\1032357238.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   SH['Total_KM_State_Highway'] = SH.sum(axis=1)

# %%
State_Highway = SH[['State','Total_KM_State_Highway']].sort_values(by = 'Total_KM_State_Highway', ascending = False).head(3)
State_Highway
# Out:
#            State  Total_KM_State_Highway
# 14   Maharashtra                  203311
# 11     Karnataka                  124464
# 6        Gujarat                  110735

# %% [markdown]
# # PWD Road

# %%
PWD= pd.read_excel("C:/Users/HP/Downloads/PWD Road.xlsx")

# %%
PWD
# Out:
#                  State    2008    2009    2010    2011    2012    2013
# 0       Andhra Pradesh   53886   55194   55466   55658   55968   56171
# 1    Arunachal Pradesh   12967   12967   12967   12967    3856   15089
# 2                Assam   31813   31813   31813   31813   42366   42366
# 3                Bihar   74672    8158    8966    8966    9030    9401
# 4         Chhattisgarh   28663   28887   25983   25983   25061   25062
# 5                  Goa    4501    4501    4501    4501    4501    4501
# 6              Gujarat   52421   52426   52557   52557   55835   56790
# 7              Haryana   20108   20332   20220   22905   22949   23018
# 8     Himachal Pradesh   28428   29353   30074   30638   31201   29908
# 9     Jammu & Kashmir     5466    6965    7488    8203    8932    9543
# 10           Jharkhand    4994    4994    4994    4994    5444    6191
# 11           Karnataka   37943   47836   50436   49959   49905   49884
# ...

# %%
PWD.dtypes
# Out:
# State    object
# 2008     object
# 2009      int64
# 2010      int64
# 2011      int64
# 2012      int64
# 2013      int64
# dtype: object

# %%
PWD.replace({2013:{'…':0}},inplace=True)

# %%
PWD['Total_KM_PWD_Road'] = PWD.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\2937078461.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   PWD['Total_KM_PWD_Road'] = PWD.sum(axis=1)

# %%
PWD_Road = PWD[['State','Total_KM_PWD_Road']].sort_values(by = 'Total_KM_PWD_Road', ascending = False).head(3)
PWD_Road
# Out:
#              State  Total_KM_PWD_Road
# 14     Maharashtra            1039998
# 25   Uttar Pradesh             843662
# 21       Rajasthan             506253

# %% [markdown]
# # Urban Road

# %%
UR= pd.read_excel("C:/Users/HP/Downloads/Urban Road.xlsx")

# %%
UR
# Out:
#                  State   2008   2009   2010   2011    2012   2013
# 0       Andhra Pradesh  13799  13811  13820  13843   13759  13628
# 1    Arunachal Pradesh     14     53     53     53      53     18
# 2                Assam   5747   6418   6520   6664    6710   4518
# 3                Bihar   9854   9864   9883   9975    8918   8760
# 4         Chhattisgarh   6553   6867   7326   8031    8116   8109
# 5                  Goa   1193    468    469    479     591    518
# 6              Gujarat  19306  21231  21718  21687   21870  22199
# 7              Haryana   5024   7984   8552   9930   10492  10211
# 8     Himachal Pradesh   2168   2158   2199   2213    2257   1852
# 9     Jammu & Kashmir    1762   1762   1762   1762    1762   1185
# 10           Jharkhand    313    514    514    514     671    620
# 11           Karnataka  24070  24070  24078  24090   42972  42909
# 12              Kerala  13289  13292  13296  13305   18922  18923
# ...

# %%
UR.dtypes
# Out:
# State    object
# 2008     object
# 2009     object
# 2010     object
# 2011     object
# 2012     object
# 2013     object
# dtype: object

# %%
 UR.replace({2008:{'..':0}},inplace=True)
 UR.replace({2009:{'..':0}},inplace=True)
 UR.replace({2010:{'..':0}},inplace=True)
 UR.replace({2011:{'..':0}},inplace=True)
 UR.replace({2012:{'..':0}},inplace=True)
 UR.replace({2013:{'..':0}},inplace=True)

# %%
UR['Total_KM_Urban_Road'] = UR.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\1879345788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   UR['Total_KM_Urban_Road'] = UR.sum(axis=1)

# %%
Urban_Road = UR[['State','Total_KM_Urban_Road']].sort_values(by = 'Total_KM_Urban_Road', ascending = False).head(3)
Urban_Road
# Out:
#              State  Total_KM_Urban_Road
# 27     West Bengal               499755
# 25   Uttar Pradesh               403603
# 11       Karnataka               182189

# %% [markdown]
# # Project Road

# %%
PR= pd.read_excel("C:/Users/HP/Downloads/Project Road.xlsx")

# %%
PR
# Out:
#                  State   2008   2009   2010   2011   2012   2013
# 0       Andhra Pradesh   8657   7463   7476   7453   7507   7620
# 1    Arunachal Pradesh   1118   1088   1088   1088   5699   5699
# 2                Assam   8061   8087   8298   8493  11348  13090
# 3                Bihar   2328   2850   2850   2850   2848   2848
# 4         Chhattisgarh  15054  15204  15345  15557  15575  18241
# 5                  Goa    120    215    215    215    196    180
# 6              Gujarat   8777   8686   8688   8688  10911  11029
# 7              Haryana    559    559    559    559    559    576
# 8     Himachal Pradesh   2110   2264   2264   2253   3273   3308
# 9     Jammu & Kashmir   11043  11054  11058  11078  18723  18723
# 10           Jharkhand   8533   8541   8541   8541   8821   8822
# 11           Karnataka  24135  24151  24151  24151  22328  23307
# 12              Kerala   8011   8084   8119   8156   7963   7975
# ...

# %%
PR.dtypes
# Out:
# State    object
# 2008     object
# 2009     object
# 2010     object
# 2011     object
# 2012     object
# 2013     object
# dtype: object

# %%
 PR.replace({2008:{'..':0}},inplace=True)
 PR.replace({2009:{'..':0}},inplace=True)
 PR.replace({2010:{'..':0}},inplace=True)
 PR.replace({2011:{'..':0}},inplace=True)
 PR.replace({2012:{'..':0}},inplace=True)
 PR.replace({2013:{'..':0}},inplace=True)

# %%
PR['Total_KM_Project_Road'] = PR.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\786244976.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   PR['Total_KM_Project_Road'] = PR.sum(axis=1)

# %%
Project_Road = PR[['State','Total_KM_Project_Road']].sort_values(by = 'Total_KM_Project_Road', ascending = False).head(3)
Project_Road
# Out:
#               State  Total_KM_Project_Road
# 25    Uttar Pradesh                 251573
# 13   Madhya Pradesh                 186582
# 14      Maharashtra                 162562

# %% [markdown]
# # Rural Road

# %%
RR= pd.read_excel("C:/Users/HP/Downloads/Rural Road.xlsx")

# %%
RR
# Out:
#                  State    2012    2013
# 0       Andhra Pradesh  164026  168516
# 1    Arunachal Pradesh    3345    5262
# 2                Assam  217734  222087
# 3                Bihar  108759  167579
# 4         Chhattisgarh   19462   30295
# 5                  Goa    5246    5851
# 6              Gujarat   52022   53288
# 7              Haryana    4484    4622
# 8     Himachal Pradesh   10585   15145
# 9     Jammu & Kashmir     5624   13451
# 10           Jharkhand    7285   17097
# 11           Karnataka  162753  163957
# 12              Kerala  155285  124864
# 13      Madhya Pradesh   96611  117722
# 14         Maharashtra  123497  262371
# 15             Manipur    6680    7635
# 16           Meghalaya    1613    1793
# 17             Mizoram    2103    2561
# 18            Nagaland   22120   23783
# 19              Orissa  194151  213446
# 20              Punjab   59495   62900
# 21           Rajasthan   92904  103441
# 22              Sikkim    2401    3343
# ...

# %%
RR.dtypes
# Out:
# State    object
# 2012     object
# 2013     object
# dtype: object

# %%
 RR.replace({2012:{'..':0}},inplace=True)
 RR.replace({2013:{'..':0}},inplace=True)

# %%
RR['Total_KM_Rural_Road'] = RR.sum(axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17632\878960397.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   RR['Total_KM_Rural_Road'] = RR.sum(axis=1)

# %%
Rural_Road = RR[['State','Total_KM_Rural_Road']].sort_values(by = 'Total_KM_Rural_Road', ascending = False).head(3)
Rural_Road
# Out:
#            State  Total_KM_Rural_Road
# 2          Assam               439821
# 19        Orissa               407597
# 14   Maharashtra               385868

# %%
import functools

Result=functools.reduce(lambda x,y : pd.merge(x,y, 
                                       on='State', 
                                       how='outer'), 
                 [National_Highway, State_Highway, PWD_Road, Urban_Road, Project_Road, Rural_Road])

# %%
Result
# Out:
#              State  Total_KM_National_Highway  Total_KM_State_Highway  \
# 0    Uttar Pradesh                    41832.0                     NaN
# 1        Rajasthan                    36650.0                     NaN
# 2   Madhya Pradesh                    29574.0                     NaN
# 3      Maharashtra                        NaN                203311.0
# 4        Karnataka                        NaN                124464.0
# 5          Gujarat                        NaN                110735.0
# 6      West Bengal                        NaN                     NaN
# 7            Assam                        NaN                     NaN
# 8           Orissa                        NaN                     NaN
#
#    Total_KM_PWD_Road  Total_KM_Urban_Road  Total_KM_Project_Road  \
# 0           843662.0             403603.0               251573.0
# 1           506253.0                  NaN                    NaN
# 2                NaN                  NaN               186582.0
# ...
